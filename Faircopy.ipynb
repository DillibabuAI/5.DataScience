# %%
from Univariate import Univariate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7684\1807352889.py in <module>
# ----> 1 from Univariate import Univariate
#
# ModuleNotFoundError: No module named 'Univariate'

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset

# %%
quan,qual=Univariate.quanQual(dataset)

# %%
quan

# %%
qual
